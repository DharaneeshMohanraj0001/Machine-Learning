# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import DBSCAN

data_points


scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

dbscan = DBSCAN(eps=0.5, min_samples=5)
clusters = dbscan.fit_predict(X_scaled)

plt.figure(figsize=(8,6))
plt.scatter(X_scaled[:,0], X_scaled[:,1], c=clusters, cmap='rainbow', s=50)
plt.title("DBSCAN Clustering")
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.show()

print("Cluster labels assigned to data points:", clusters)
# Out:
# First 5 rows of dataset:
#     Feature1  Feature2
# 0  -9.113944  6.813616
# 1  -9.354576  7.092790
# 2  -2.015671  8.281780
# 3  -7.010236 -6.220843
# 4 -10.061202  6.718671
# Cluster labels assigned to data points: [0 0 1 2 0 2 3 2 1 3 1 3 1 1 0 1 0 3 1 1 3 1 2 0 1 0 0 2 2 3 1 3 0 3 0 1 0
#  2 0 2 3 1 0 2 1 1 0 3 0 3 2 0 2 1 2 3 0 3 3 1 0 3 3 0 2 2 2 2 2 1 2 2 0 3
#  1 0 2 2 1 2 1 1 0 1 2 0 0 3 3 3 0 1 0 1 1 0 2 1 0 0 3 3 3 1 1 1 1 1 2 0 3
#  1 1 1 1 3 0 2 0 2 2 2 1 0 2 0 0 1 0 2 3 1 1 1 1 3 3 0 1 2 1 3 2 1 3 3 3 3
#  2 1 1 0 3 2 1 3 2 0 0 3 1 0 2 0 3 0 2 1 1 1 1 1 2 3 3 2 2 3 3 2 0 1 0 3 3
#  0 2 1 3 3 2 2 2 0 3 2 2 3 3 0 1 1 2 3 1 2 2 0 2 1 1 2 2 3 0 2 0 0 1 0 0 2
#  0 2 3 3 0 0 3 3 3 0 1 2 3 2 0 3 0 0 0 2 2 3 0 2 2 2 0 2 0 2 0 3 2 0 3 1 0
#  1 3 1 0 1 2 3 2 3 3 1 1 2 3 3 0 0 2 1 1 3 3 3 3 2 0 3 2 3 3 2 1 2 3 1 0 1
#  3 1 0 0]
